# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set(style='whitegrid', palette='muted', color_codes=True)
plt.plot(np.arange(3),['x','y','z'])

# %%
sns.set(style='ticks')
data = sns.load_dataset('iris')
sns.pairplot(data)
